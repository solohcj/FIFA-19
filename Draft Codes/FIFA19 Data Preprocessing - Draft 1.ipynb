# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv("FIFA19.csv")

# %%
raw_data.head()
# Out:
#     ID          Name  Age                                        Photo  \
# 0   16   Luis García   37   https://cdn.sofifa.org/players/4/19/16.png
# 1   41       Iniesta   34   https://cdn.sofifa.org/players/4/19/41.png
# 2   80  E. Belözoğlu   37   https://cdn.sofifa.org/players/4/19/80.png
# 3  164      G. Pinzi   37  https://cdn.sofifa.org/players/4/19/164.png
# 4  657    D. Vaughan   35  https://cdn.sofifa.org/players/4/19/657.png
#
#   Nationality                                 Flag  Overall  Potential  \
# 0       Spain  https://cdn.sofifa.org/flags/45.png       71         71
# 1       Spain  https://cdn.sofifa.org/flags/45.png       86         86
# 2      Turkey  https://cdn.sofifa.org/flags/48.png       79         79
# 3       Italy  https://cdn.sofifa.org/flags/27.png       70         70
# 4       Wales  https://cdn.sofifa.org/flags/50.png       66         66
#
#                     Club                                        Club Logo  \
# ...

# %%
raw_data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data=raw_data.copy()
data=data.drop(["Photo", "Flag", "Club", "Club Logo", "Jersey Number", "Real Face", "Joined", "Loaned From", "Contract Valid Until"], axis=1)
data.head()
# Out:
#     ID          Name  Age Nationality  Overall  Potential   Value  Wage  \
# 0   16   Luis García   37       Spain       71         71   €750K   €6K
# 1   41       Iniesta   34       Spain       86         86  €21.5M  €21K
# 2   80  E. Belözoğlu   37      Turkey       79         79     €4M  €23K
# 3  164      G. Pinzi   37       Italy       70         70   €240K   €2K
# 4  657    D. Vaughan   35       Wales       66         66   €150K   €4K
#
#    Special Preferred Foot  ...  Composure  Marking  StandingTackle  \
# 0     1906          Right  ...       79.0     70.0            43.0
# 1     2058          Right  ...       89.0     67.0            57.0
# 2     2047           Left  ...       80.0     65.0            67.0
# 3     1882          Right  ...       68.0     74.0            71.0
# 4     1781           Left  ...       82.0     59.0            66.0
#
#   SlidingTackle GKDiving GKHandling GKKicking GKPositioning GKReflexes  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
# ...

# %%
pd.set_option("display.max_columns", None)
data.describe(include="all")
# Out:
#                    ID          Name           Age Nationality       Overall  \
# count    18207.000000         18207  18207.000000       18207  18207.000000
# unique            NaN         17194           NaN         164           NaN
# top               NaN  J. Rodríguez           NaN     England           NaN
# freq              NaN            11           NaN        1662           NaN
# mean    214298.338606           NaN     25.122206         NaN     66.238699
# std      29965.244204           NaN      4.669943         NaN      6.908930
# min         16.000000           NaN     16.000000         NaN     46.000000
# 25%     200315.500000           NaN     21.000000         NaN     62.000000
# 50%     221759.000000           NaN     25.000000         NaN     66.000000
# 75%     236529.500000           NaN     28.000000         NaN     71.000000
# max     246620.000000           NaN     45.000000         NaN     94.000000
#
# ...

# %%
#GK = data[data["Position"]=="GK"].count()
#GK

# %%
data["Value"].shape[0]
# Out:
# 18207

# %% [markdown]
# ## Changing the "Value" from string to float

# %%
val=data.iloc[:,6]
remove_unit = []

for i in range(val.shape[0]):
    remove_unit.append(val[i].strip("€"))

# %%
remove_unit
# Out:
# ['750K',
#  '21.5M',
#  '4M',
#  '240K',
#  '150K',
#  '2.7M',
#  '4M',
#  '950K',
#  '130K',
#  '30K',
#  '3.2M',
#  '140K',
#  ' 0',
#  '1.5M',
#  '425K',
#  '270K',
#  '750K',
#  '15.5M',
#  '70K',
#  '240K',
#  '50K',
#  '160K',
#  '100K',
#  '10K',
#  '10K',
#  '150K',
#  '210K',
#  '80K',
#  '525K',
#  '160K',
#  '210K',
#  '70K',
#  '1.8M',
#  '270K',
#  '10K',
#  '450K',
#  '130K',
#  '120K',
#  '150K',
#  '2.1M',
#  '750K',
#  '240K',
#  '170K',
#  '15.5M',
#  '3.9M',
#  '77M',
#  '40K',
#  '400K',
#  '425K',
#  '1.3M',
#  '6M',
#  '1.6M',
#  '90K',
#  '40K',
#  '10K',
#  '20K',
#  ' 0',
#  '210K',
#  '270K',
#  '325K',
#  '200K',
#  '14M',
#  '950K',
#  '6M',
#  '240K',
#  '270K',
#  '900K',
#  '325K',
#  '250K',
#  '1.8M',
#  '900K',
#  '280K',
#  '100K',
#  '1.8M',
#  '20K',
#  '425K',
#  '3M',
#  '900K',
#  '1M',
#  '1.6M',
#  '325K',
#  '60K',
#  '8M',
#  '1.6M',
#  '1.7M',
#  ' 0',
#  '20K',
#  '140K',
#  '450K',
#  '1.9M',
#  '60K',
#  '300K',
#  '400K',
#  '120K',
# ...

# %%
remove_multiplier_K = []

for i in range(len(remove_unit)):
    remove_multiplier_K.append(remove_unit[i].strip("K"))

# %%
remove_multiplier_M = []

for i in range(len(remove_multiplier_K)):
    remove_multiplier_M.append(remove_multiplier_K[i].strip("M"))

# %%
val_conversion = np.asarray(remove_multiplier_M)
val_conversion = val_conversion.astype(float)
type(val_conversion[4])
# Out:
# numpy.float64

# %%
type(val_conversion[4])
# Out:
# numpy.float64

# %%
remove_unit[4][-1]
# Out:
# 'K'

# %%
for i in range(len(val_conversion)):
    if remove_unit[i][-1]=="K":
        val_conversion[i]*=1000
    if remove_unit[i][-1]=="M":
        val_conversion[i]*=1000000

# %%
val_conversion
# Out:
# array([  750000., 21500000.,  4000000., ...,   180000.,   650000.,
#           70000.])

# %%
remove_unit[777]
# Out:
# '3.6M'

# %%
val_conversion[777]
# Out:
# 3600000.0

# %%
type(val_conversion[777])
# Out:
# numpy.float64

# %%
type(data["CF"][2])
# Out:
# str
