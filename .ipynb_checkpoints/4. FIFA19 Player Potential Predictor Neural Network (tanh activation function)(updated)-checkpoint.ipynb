# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
sns.set()

# %% [markdown]
# ## Data

# %%
npz = np.load("FIFA19_data_train(updated).npz")
train_inputs, train_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.float)

npz = np.load("FIFA19_data_validation(updated).npz")
validation_inputs, validation_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.float)

npz = np.load("FIFA19_data_test(updated).npz")
test_inputs, test_targets = npz["inputs"].astype(np.float), npz["targets"].astype(float)

# %% [markdown]
# ## Model

# %%
input_size = 328
output_size = 1

hidden_layer_size = 10

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation="tanh"),
    tf.keras.layers.Dense(hidden_layer_size, activation="tanh"),
    tf.keras.layers.Dense(output_size, activation="linear"),
])

#amsgrad = tf.keras.optimizers.Adam(amsgrad=True)

model.compile(optimizer="adam", loss="mean_squared_error", metrics=["mean_absolute_error"])

batch_size = 100
max_epochs = 200

early_stopping = tf.keras.callbacks.EarlyStopping(patience=4)

hist = model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          callbacks = [early_stopping],
          validation_data = (validation_inputs, validation_targets),
          verbose = 2
          )
# Out:
# Train on 14512 samples, validate on 1814 samples
# Epoch 1/200
# 14512/14512 - 1s - loss: 4901.3268 - mean_absolute_error: 69.7130 - val_loss: 4586.1089 - val_mean_absolute_error: 67.4333
# Epoch 2/200
# 14512/14512 - 0s - loss: 4305.3563 - mean_absolute_error: 65.2763 - val_loss: 4126.1886 - val_mean_absolute_error: 63.9050
# Epoch 3/200
# 14512/14512 - 0s - loss: 3972.5808 - mean_absolute_error: 62.6633 - val_loss: 3869.5923 - val_mean_absolute_error: 61.8434
# Epoch 4/200
# 14512/14512 - 0s - loss: 3740.0731 - mean_absolute_error: 60.7600 - val_loss: 3655.2216 - val_mean_absolute_error: 60.0621
# Epoch 5/200
# 14512/14512 - 0s - loss: 3534.6880 - mean_absolute_error: 59.0267 - val_loss: 3460.4653 - val_mean_absolute_error: 58.3934
# Epoch 6/200
# 14512/14512 - 0s - loss: 3346.2744 - mean_absolute_error: 57.3853 - val_loss: 3278.7099 - val_mean_absolute_error: 56.7899
# Epoch 7/200
# 14512/14512 - 0s - loss: 3169.2995 - mean_absolute_error: 55.7989 - val_loss: 3106.6512 - val_mean_absolute_error: 55.2292
# Epoch 8/200
# 14512/14512 - 0s - loss: 2999.2982 - mean_absolute_error: 54.2353 - val_loss: 2939.4372 - val_mean_absolute_error: 53.6750
# Epoch 9/200
# 14512/14512 - 0s - loss: 2834.5553 - mean_absolute_error: 52.6794 - val_loss: 2780.0002 - val_mean_absolute_error: 52.1469
# Epoch 10/200
# 14512/14512 - 0s - loss: 2680.2432 - mean_absolute_error: 51.1742 - val_loss: 2629.1869 - val_mean_absolute_error: 50.6580
# Epoch 11/200
# 14512/14512 - 0s - loss: 2532.0123 - mean_absolute_error: 49.6888 - val_loss: 2483.1160 - val_mean_absolute_error: 49.1780
# Epoch 12/200
# 14512/14512 - 0s - loss: 2388.0066 - mean_absolute_error: 48.2065 - val_loss: 2341.8754 - val_mean_absolute_error: 47.7110
# Epoch 13/200
# 14512/14512 - 0s - loss: 2249.6935 - mean_absolute_error: 46.7457 - val_loss: 2204.8130 - val_mean_absolute_error: 46.2507
# Epoch 14/200
# 14512/14512 - 0s - loss: 2115.6518 - mean_absolute_error: 45.2920 - val_loss: 2072.1438 - val_mean_absolute_error: 44.7974
# Epoch 15/200
# 14512/14512 - 0s - loss: 1985.6648 - mean_absolute_error: 43.8405 - val_loss: 1942.7754 - val_mean_absolute_error: 43.3445
# Epoch 16/200
# 14512/14512 - 0s - loss: 1859.1841 - mean_absolute_error: 42.3939 - val_loss: 1816.5761 - val_mean_absolute_error: 41.8945
# Epoch 17/200
# 14512/14512 - 0s - loss: 1737.0660 - mean_absolute_error: 40.9555 - val_loss: 1696.0453 - val_mean_absolute_error: 40.4568
# Epoch 18/200
# 14512/14512 - 0s - loss: 1620.0707 - mean_absolute_error: 39.5257 - val_loss: 1580.5200 - val_mean_absolute_error: 39.0299
# Epoch 19/200
# 14512/14512 - 0s - loss: 1507.3010 - mean_absolute_error: 38.1011 - val_loss: 1468.0864 - val_mean_absolute_error: 37.6044
# Epoch 20/200
# 14512/14512 - 0s - loss: 1397.2743 - mean_absolute_error: 36.6773 - val_loss: 1357.4638 - val_mean_absolute_error: 36.1748
# Epoch 21/200
# 14512/14512 - 0s - loss: 1291.8973 - mean_absolute_error: 35.2659 - val_loss: 1253.7523 - val_mean_absolute_error: 34.7629
# Epoch 22/200
# 14512/14512 - 0s - loss: 1192.2466 - mean_absolute_error: 33.8680 - val_loss: 1154.9254 - val_mean_absolute_error: 33.3612
# Epoch 23/200
# 14512/14512 - 0s - loss: 1096.7277 - mean_absolute_error: 32.4727 - val_loss: 1061.0585 - val_mean_absolute_error: 31.9709
# Epoch 24/200
# 14512/14512 - 0s - loss: 1007.5262 - mean_absolute_error: 31.1044 - val_loss: 973.9304 - val_mean_absolute_error: 30.6074
# Epoch 25/200
# 14512/14512 - 0s - loss: 925.2246 - mean_absolute_error: 29.7659 - val_loss: 893.5848 - val_mean_absolute_error: 29.2807
# Epoch 26/200
# 14512/14512 - 0s - loss: 848.5079 - mean_absolute_error: 28.4575 - val_loss: 818.6658 - val_mean_absolute_error: 27.9820
# Epoch 27/200
# 14512/14512 - 0s - loss: 777.0372 - mean_absolute_error: 27.1788 - val_loss: 749.1586 - val_mean_absolute_error: 26.7153
# Epoch 28/200
# 14512/14512 - 0s - loss: 710.2534 - mean_absolute_error: 25.9220 - val_loss: 684.0951 - val_mean_absolute_error: 25.4720
# Epoch 29/200
# 14512/14512 - 0s - loss: 647.9612 - mean_absolute_error: 24.6941 - val_loss: 623.3224 - val_mean_absolute_error: 24.2526
# Epoch 30/200
# 14512/14512 - 0s - loss: 589.7915 - mean_absolute_error: 23.4875 - val_loss: 566.7278 - val_mean_absolute_error: 23.0581
# Epoch 31/200
# 14512/14512 - 0s - loss: 535.5292 - mean_absolute_error: 22.3028 - val_loss: 514.7886 - val_mean_absolute_error: 21.8967
# Epoch 32/200
# 14512/14512 - 0s - loss: 485.0742 - mean_absolute_error: 21.1414 - val_loss: 465.6139 - val_mean_absolute_error: 20.7471
# Epoch 33/200
# 14512/14512 - 0s - loss: 438.0719 - mean_absolute_error: 20.0016 - val_loss: 421.1900 - val_mean_absolute_error: 19.6374
# Epoch 34/200
# 14512/14512 - 0s - loss: 394.6636 - mean_absolute_error: 18.8871 - val_loss: 379.2296 - val_mean_absolute_error: 18.5337
# Epoch 35/200
# 14512/14512 - 0s - loss: 354.2853 - mean_absolute_error: 17.7886 - val_loss: 340.2882 - val_mean_absolute_error: 17.4502
# Epoch 36/200
# 14512/14512 - 0s - loss: 317.2264 - mean_absolute_error: 16.7184 - val_loss: 304.4717 - val_mean_absolute_error: 16.3934
# Epoch 37/200
# 14512/14512 - 0s - loss: 283.2108 - mean_absolute_error: 15.6732 - val_loss: 271.6519 - val_mean_absolute_error: 15.3642
# Epoch 38/200
# 14512/14512 - 0s - loss: 252.1114 - mean_absolute_error: 14.6523 - val_loss: 241.5727 - val_mean_absolute_error: 14.3583
# Epoch 39/200
# 14512/14512 - 0s - loss: 223.8202 - mean_absolute_error: 13.6622 - val_loss: 214.3248 - val_mean_absolute_error: 13.3846
# Epoch 40/200
# 14512/14512 - 0s - loss: 198.2076 - mean_absolute_error: 12.7079 - val_loss: 189.6660 - val_mean_absolute_error: 12.4476
# Epoch 41/200
# 14512/14512 - 0s - loss: 175.1016 - mean_absolute_error: 11.7884 - val_loss: 167.4847 - val_mean_absolute_error: 11.5504
# Epoch 42/200
# 14512/14512 - 0s - loss: 154.4371 - mean_absolute_error: 10.9159 - val_loss: 147.6599 - val_mean_absolute_error: 10.6923
# Epoch 43/200
# 14512/14512 - 0s - loss: 136.0651 - mean_absolute_error: 10.0884 - val_loss: 130.0625 - val_mean_absolute_error: 9.8811
# Epoch 44/200
# 14512/14512 - 0s - loss: 119.8127 - mean_absolute_error: 9.3137 - val_loss: 114.5022 - val_mean_absolute_error: 9.1235
# Epoch 45/200
# 14512/14512 - 0s - loss: 105.5429 - mean_absolute_error: 8.5978 - val_loss: 100.8748 - val_mean_absolute_error: 8.4235
# Epoch 46/200
# 14512/14512 - 0s - loss: 93.1935 - mean_absolute_error: 7.9502 - val_loss: 89.1534 - val_mean_absolute_error: 7.7890
# Epoch 47/200
# 14512/14512 - 0s - loss: 82.5581 - mean_absolute_error: 7.3767 - val_loss: 78.9612 - val_mean_absolute_error: 7.2180
# Epoch 48/200
# 14512/14512 - 0s - loss: 73.5183 - mean_absolute_error: 6.8760 - val_loss: 70.3667 - val_mean_absolute_error: 6.7349
# Epoch 49/200
# 14512/14512 - 0s - loss: 65.9033 - mean_absolute_error: 6.4421 - val_loss: 63.1376 - val_mean_absolute_error: 6.3151
# Epoch 50/200
# 14512/14512 - 0s - loss: 59.5591 - mean_absolute_error: 6.0838 - val_loss: 57.0350 - val_mean_absolute_error: 5.9458
# Epoch 51/200
# 14512/14512 - 0s - loss: 54.3232 - mean_absolute_error: 5.7819 - val_loss: 51.8901 - val_mean_absolute_error: 5.6485
# Epoch 52/200
# 14512/14512 - 0s - loss: 49.5064 - mean_absolute_error: 5.4823 - val_loss: 47.2410 - val_mean_absolute_error: 5.3535
# Epoch 53/200
# 14512/14512 - 0s - loss: 44.7727 - mean_absolute_error: 5.1757 - val_loss: 42.0565 - val_mean_absolute_error: 4.9835
# Epoch 54/200
# 14512/14512 - 0s - loss: 39.9997 - mean_absolute_error: 4.8181 - val_loss: 37.6586 - val_mean_absolute_error: 4.6405
# Epoch 55/200
# 14512/14512 - 0s - loss: 35.8455 - mean_absolute_error: 4.4988 - val_loss: 33.6484 - val_mean_absolute_error: 4.3215
# Epoch 56/200
# 14512/14512 - 0s - loss: 32.1929 - mean_absolute_error: 4.1981 - val_loss: 29.8583 - val_mean_absolute_error: 4.0101
# Epoch 57/200
# 14512/14512 - 0s - loss: 28.8184 - mean_absolute_error: 3.9041 - val_loss: 26.8370 - val_mean_absolute_error: 3.7553
# Epoch 58/200
# 14512/14512 - 0s - loss: 25.9788 - mean_absolute_error: 3.6565 - val_loss: 24.2553 - val_mean_absolute_error: 3.5402
# Epoch 59/200
# 14512/14512 - 0s - loss: 23.5590 - mean_absolute_error: 3.4451 - val_loss: 22.1595 - val_mean_absolute_error: 3.3465
# Epoch 60/200
# 14512/14512 - 0s - loss: 21.4933 - mean_absolute_error: 3.2519 - val_loss: 20.0283 - val_mean_absolute_error: 3.1484
# Epoch 61/200
# 14512/14512 - 0s - loss: 19.7257 - mean_absolute_error: 3.0916 - val_loss: 18.3704 - val_mean_absolute_error: 2.9896
# Epoch 62/200
# 14512/14512 - 0s - loss: 18.2332 - mean_absolute_error: 2.9560 - val_loss: 16.9470 - val_mean_absolute_error: 2.8480
# Epoch 63/200
# 14512/14512 - 0s - loss: 16.9750 - mean_absolute_error: 2.8339 - val_loss: 15.8506 - val_mean_absolute_error: 2.7410
# Epoch 64/200
# 14512/14512 - 0s - loss: 15.8627 - mean_absolute_error: 2.7268 - val_loss: 14.8399 - val_mean_absolute_error: 2.6286
# Epoch 65/200
# 14512/14512 - 0s - loss: 14.8818 - mean_absolute_error: 2.6235 - val_loss: 13.5656 - val_mean_absolute_error: 2.5082
# Epoch 66/200
# 14512/14512 - 0s - loss: 14.0360 - mean_absolute_error: 2.5383 - val_loss: 12.6196 - val_mean_absolute_error: 2.4285
# Epoch 67/200
# 14512/14512 - 0s - loss: 13.1582 - mean_absolute_error: 2.4502 - val_loss: 11.8458 - val_mean_absolute_error: 2.3464
# Epoch 68/200
# 14512/14512 - 0s - loss: 12.3751 - mean_absolute_error: 2.3557 - val_loss: 11.3341 - val_mean_absolute_error: 2.2644
# Epoch 69/200
# 14512/14512 - 0s - loss: 11.8815 - mean_absolute_error: 2.2969 - val_loss: 10.9095 - val_mean_absolute_error: 2.2341
# Epoch 70/200
# 14512/14512 - 0s - loss: 11.3829 - mean_absolute_error: 2.2425 - val_loss: 10.5984 - val_mean_absolute_error: 2.1981
# Epoch 71/200
# 14512/14512 - 0s - loss: 10.9202 - mean_absolute_error: 2.1923 - val_loss: 10.1418 - val_mean_absolute_error: 2.1328
# Epoch 72/200
# 14512/14512 - 0s - loss: 10.4961 - mean_absolute_error: 2.1400 - val_loss: 9.7472 - val_mean_absolute_error: 2.0919
# Epoch 73/200
# 14512/14512 - 0s - loss: 9.9183 - mean_absolute_error: 2.0861 - val_loss: 9.2610 - val_mean_absolute_error: 2.0440
# Epoch 74/200
# 14512/14512 - 0s - loss: 9.3962 - mean_absolute_error: 2.0271 - val_loss: 8.9729 - val_mean_absolute_error: 1.9924
# Epoch 75/200
# 14512/14512 - 0s - loss: 9.0275 - mean_absolute_error: 1.9816 - val_loss: 8.7312 - val_mean_absolute_error: 1.9559
# Epoch 76/200
# 14512/14512 - 0s - loss: 8.7266 - mean_absolute_error: 1.9416 - val_loss: 8.5284 - val_mean_absolute_error: 1.9237
# Epoch 77/200
# 14512/14512 - 0s - loss: 8.4167 - mean_absolute_error: 1.9073 - val_loss: 8.2915 - val_mean_absolute_error: 1.8972
# Epoch 78/200
# 14512/14512 - 0s - loss: 8.1473 - mean_absolute_error: 1.8717 - val_loss: 8.1891 - val_mean_absolute_error: 1.8850
# Epoch 79/200
# 14512/14512 - 0s - loss: 7.9425 - mean_absolute_error: 1.8509 - val_loss: 7.9682 - val_mean_absolute_error: 1.8532
# Epoch 80/200
# 14512/14512 - 0s - loss: 7.6862 - mean_absolute_error: 1.8179 - val_loss: 7.7825 - val_mean_absolute_error: 1.8310
# Epoch 81/200
# 14512/14512 - 0s - loss: 7.3894 - mean_absolute_error: 1.7802 - val_loss: 7.4446 - val_mean_absolute_error: 1.7934
# Epoch 82/200
# 14512/14512 - 0s - loss: 7.1463 - mean_absolute_error: 1.7493 - val_loss: 7.1758 - val_mean_absolute_error: 1.7702
# Epoch 83/200
# 14512/14512 - 0s - loss: 6.9427 - mean_absolute_error: 1.7236 - val_loss: 6.9107 - val_mean_absolute_error: 1.7326
# Epoch 84/200
# 14512/14512 - 0s - loss: 6.7487 - mean_absolute_error: 1.6985 - val_loss: 6.6768 - val_mean_absolute_error: 1.6955
# Epoch 85/200
# 14512/14512 - 0s - loss: 6.6038 - mean_absolute_error: 1.6746 - val_loss: 6.5667 - val_mean_absolute_error: 1.6904
# Epoch 86/200
# 14512/14512 - 0s - loss: 6.4522 - mean_absolute_error: 1.6494 - val_loss: 6.4702 - val_mean_absolute_error: 1.6644
# Epoch 87/200
# 14512/14512 - 0s - loss: 6.3244 - mean_absolute_error: 1.6323 - val_loss: 6.3650 - val_mean_absolute_error: 1.6536
# Epoch 88/200
# 14512/14512 - 0s - loss: 6.1578 - mean_absolute_error: 1.6095 - val_loss: 6.2510 - val_mean_absolute_error: 1.6400
# Epoch 89/200
# 14512/14512 - 0s - loss: 5.9679 - mean_absolute_error: 1.5888 - val_loss: 6.0627 - val_mean_absolute_error: 1.6003
# Epoch 90/200
# 14512/14512 - 0s - loss: 5.8570 - mean_absolute_error: 1.5765 - val_loss: 5.9398 - val_mean_absolute_error: 1.6009
# Epoch 91/200
# 14512/14512 - 0s - loss: 5.7476 - mean_absolute_error: 1.5626 - val_loss: 5.8167 - val_mean_absolute_error: 1.5835
# Epoch 92/200
# 14512/14512 - 0s - loss: 5.6272 - mean_absolute_error: 1.5419 - val_loss: 5.7382 - val_mean_absolute_error: 1.5828
# Epoch 93/200
# 14512/14512 - 0s - loss: 5.5476 - mean_absolute_error: 1.5363 - val_loss: 5.5698 - val_mean_absolute_error: 1.5520
# Epoch 94/200
# 14512/14512 - 0s - loss: 5.4646 - mean_absolute_error: 1.5224 - val_loss: 5.6113 - val_mean_absolute_error: 1.5467
# Epoch 95/200
# 14512/14512 - 0s - loss: 5.3583 - mean_absolute_error: 1.5099 - val_loss: 5.6137 - val_mean_absolute_error: 1.5516
# Epoch 96/200
# 14512/14512 - 0s - loss: 5.2720 - mean_absolute_error: 1.4982 - val_loss: 5.4990 - val_mean_absolute_error: 1.5277
# Epoch 97/200
# 14512/14512 - 0s - loss: 5.1539 - mean_absolute_error: 1.4873 - val_loss: 5.4426 - val_mean_absolute_error: 1.5361
# Epoch 98/200
# 14512/14512 - 0s - loss: 5.0623 - mean_absolute_error: 1.4761 - val_loss: 5.3898 - val_mean_absolute_error: 1.5227
# Epoch 99/200
# 14512/14512 - 0s - loss: 4.9815 - mean_absolute_error: 1.4633 - val_loss: 5.4367 - val_mean_absolute_error: 1.5311
# Epoch 100/200
# 14512/14512 - 0s - loss: 4.9129 - mean_absolute_error: 1.4565 - val_loss: 5.3277 - val_mean_absolute_error: 1.5133
# Epoch 101/200
# 14512/14512 - 0s - loss: 4.8588 - mean_absolute_error: 1.4509 - val_loss: 5.2370 - val_mean_absolute_error: 1.5017
# Epoch 102/200
# 14512/14512 - 0s - loss: 4.7567 - mean_absolute_error: 1.4385 - val_loss: 5.1806 - val_mean_absolute_error: 1.5014
# Epoch 103/200
# 14512/14512 - 0s - loss: 4.6498 - mean_absolute_error: 1.4346 - val_loss: 5.0437 - val_mean_absolute_error: 1.5110
# Epoch 104/200
# 14512/14512 - 0s - loss: 4.4511 - mean_absolute_error: 1.4168 - val_loss: 4.8544 - val_mean_absolute_error: 1.4834
# Epoch 105/200
# 14512/14512 - 0s - loss: 4.2792 - mean_absolute_error: 1.4021 - val_loss: 4.7400 - val_mean_absolute_error: 1.4778
# Epoch 106/200
# 14512/14512 - 0s - loss: 4.1412 - mean_absolute_error: 1.3873 - val_loss: 4.6769 - val_mean_absolute_error: 1.4729
# Epoch 107/200
# 14512/14512 - 0s - loss: 4.0162 - mean_absolute_error: 1.3755 - val_loss: 4.6376 - val_mean_absolute_error: 1.4684
# Epoch 108/200
# 14512/14512 - 0s - loss: 3.9175 - mean_absolute_error: 1.3651 - val_loss: 4.5125 - val_mean_absolute_error: 1.4630
# Epoch 109/200
# 14512/14512 - 0s - loss: 3.8341 - mean_absolute_error: 1.3529 - val_loss: 4.5757 - val_mean_absolute_error: 1.4620
# Epoch 110/200
# 14512/14512 - 0s - loss: 3.7683 - mean_absolute_error: 1.3450 - val_loss: 4.4545 - val_mean_absolute_error: 1.4395
# Epoch 111/200
# 14512/14512 - 0s - loss: 3.6864 - mean_absolute_error: 1.3398 - val_loss: 4.3970 - val_mean_absolute_error: 1.4270
# Epoch 112/200
# 14512/14512 - 0s - loss: 3.5817 - mean_absolute_error: 1.3230 - val_loss: 4.3181 - val_mean_absolute_error: 1.4265
# Epoch 113/200
# 14512/14512 - 0s - loss: 3.5304 - mean_absolute_error: 1.3171 - val_loss: 4.2696 - val_mean_absolute_error: 1.4113
# Epoch 114/200
# 14512/14512 - 0s - loss: 3.4639 - mean_absolute_error: 1.3077 - val_loss: 4.1899 - val_mean_absolute_error: 1.4003
# Epoch 115/200
# 14512/14512 - 0s - loss: 3.4176 - mean_absolute_error: 1.3043 - val_loss: 4.1287 - val_mean_absolute_error: 1.3988
# Epoch 116/200
# 14512/14512 - 0s - loss: 3.3485 - mean_absolute_error: 1.2898 - val_loss: 4.0732 - val_mean_absolute_error: 1.3855
# Epoch 117/200
# 14512/14512 - 0s - loss: 3.2842 - mean_absolute_error: 1.2827 - val_loss: 4.0026 - val_mean_absolute_error: 1.3816
# Epoch 118/200
# 14512/14512 - 0s - loss: 3.2345 - mean_absolute_error: 1.2752 - val_loss: 3.9802 - val_mean_absolute_error: 1.3801
# Epoch 119/200
# 14512/14512 - 0s - loss: 3.2010 - mean_absolute_error: 1.2755 - val_loss: 3.9615 - val_mean_absolute_error: 1.3730
# Epoch 120/200
# 14512/14512 - 0s - loss: 3.1624 - mean_absolute_error: 1.2668 - val_loss: 3.8987 - val_mean_absolute_error: 1.3665
# Epoch 121/200
# 14512/14512 - 0s - loss: 3.1048 - mean_absolute_error: 1.2589 - val_loss: 3.8816 - val_mean_absolute_error: 1.3650
# Epoch 122/200
# 14512/14512 - 0s - loss: 3.0771 - mean_absolute_error: 1.2603 - val_loss: 3.8457 - val_mean_absolute_error: 1.3601
# Epoch 123/200
# 14512/14512 - 0s - loss: 3.0407 - mean_absolute_error: 1.2505 - val_loss: 3.8215 - val_mean_absolute_error: 1.3526
# Epoch 124/200
# 14512/14512 - 0s - loss: 3.0022 - mean_absolute_error: 1.2453 - val_loss: 3.8145 - val_mean_absolute_error: 1.3579
# Epoch 125/200
# 14512/14512 - 0s - loss: 2.9424 - mean_absolute_error: 1.2348 - val_loss: 3.7251 - val_mean_absolute_error: 1.3473
# Epoch 126/200
# 14512/14512 - 0s - loss: 2.9380 - mean_absolute_error: 1.2381 - val_loss: 3.6484 - val_mean_absolute_error: 1.3178
# Epoch 127/200
# 14512/14512 - 0s - loss: 2.8971 - mean_absolute_error: 1.2256 - val_loss: 3.6577 - val_mean_absolute_error: 1.3284
# Epoch 128/200
# 14512/14512 - 0s - loss: 2.8916 - mean_absolute_error: 1.2251 - val_loss: 3.7021 - val_mean_absolute_error: 1.3405
# Epoch 129/200
# 14512/14512 - 0s - loss: 2.8693 - mean_absolute_error: 1.2168 - val_loss: 3.7053 - val_mean_absolute_error: 1.3408
# Epoch 130/200
# 14512/14512 - 0s - loss: 2.8641 - mean_absolute_error: 1.2182 - val_loss: 3.6493 - val_mean_absolute_error: 1.3197

# %%
val_loss = hist.history["val_loss"][1:]
loss = hist.history["loss"][1:]
epochs = range(1, len(val_loss)+1)

plt.plot(epochs, loss, color = "b")
plt.plot(epochs, val_loss, color = "r")
plt.xlabel("No. of Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
# Out:
# Text(0, 0.5, 'Loss')

# %%
val_error = hist.history["val_mean_absolute_error"][1:]
training_error = hist.history["mean_absolute_error"][1:]
epochs = range(1, len(val_error)+1)

plt.plot(epochs, training_error, color = "b")
plt.plot(epochs, val_error, color = "r")
#plt.yticks(np.arange(0, max(training_error), 1))
#plt.xticks(np.arange(0, max(epochs)+1, 5))
plt.xlabel("No. of Epochs", fontsize=15)
plt.ylabel("Error", fontsize=15)
plt.show()

# %% [markdown]
# ## Evaluating the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 1814/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
print ("Test Loss: {:.2f}, Expected Deviation for Prediction: {:.2f}".format(test_loss, test_accuracy))
# Out:
# Test Loss: 3.62, Expected Deviation for Prediction: 1.35
