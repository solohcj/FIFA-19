# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
sns.set()

# %% [markdown]
# ## Data

# %%
npz = np.load("FIFA19_data_train.npz")
train_inputs, train_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.float)

npz = np.load("FIFA19_data_validation.npz")
validation_inputs, validation_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.float)

npz = np.load("FIFA19_data_test.npz")
test_inputs, test_targets = npz["inputs"].astype(np.float), npz["targets"].astype(float)

# %% [markdown]
# ## Model

# %%
input_size = 328
output_size = 1

hidden_layer_size = 10

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation="tanh"),
    tf.keras.layers.Dense(hidden_layer_size, activation="tanh"),
    tf.keras.layers.Dense(output_size, activation="linear"),
])

#amsgrad = tf.keras.optimizers.Adam(amsgrad=True)

model.compile(optimizer="adam", loss="mean_squared_error", metrics=["mean_absolute_error"])

batch_size = 100
max_epochs = 200

early_stopping = tf.keras.callbacks.EarlyStopping(patience=4)

hist = model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          callbacks = [early_stopping],
          validation_data = (validation_inputs, validation_targets),
          verbose = 2
          )
# Out:
# Train on 14512 samples, validate on 1814 samples
# Epoch 1/200
# 14512/14512 - 1s - loss: 4839.8100 - mean_absolute_error: 69.2919 - val_loss: 4524.5300 - val_mean_absolute_error: 66.9922
# Epoch 2/200
# 14512/14512 - 0s - loss: 4323.1557 - mean_absolute_error: 65.4406 - val_loss: 4152.1311 - val_mean_absolute_error: 64.1364
# Epoch 3/200
# 14512/14512 - 0s - loss: 4005.3082 - mean_absolute_error: 62.9525 - val_loss: 3869.9810 - val_mean_absolute_error: 61.8791
# Epoch 4/200
# 14512/14512 - 0s - loss: 3755.1841 - mean_absolute_error: 60.9190 - val_loss: 3646.8168 - val_mean_absolute_error: 60.0316
# Epoch 5/200
# 14512/14512 - 0s - loss: 3545.1052 - mean_absolute_error: 59.1549 - val_loss: 3447.0511 - val_mean_absolute_error: 58.3269
# Epoch 6/200
# 14512/14512 - 0s - loss: 3351.9956 - mean_absolute_error: 57.4869 - val_loss: 3261.6722 - val_mean_absolute_error: 56.6989
# Epoch 7/200
# 14512/14512 - 0s - loss: 3171.2196 - mean_absolute_error: 55.8776 - val_loss: 3086.8276 - val_mean_absolute_error: 55.1194
# Epoch 8/200
# 14512/14512 - 0s - loss: 3000.0903 - mean_absolute_error: 54.3117 - val_loss: 2921.0226 - val_mean_absolute_error: 53.5770
# Epoch 9/200
# 14512/14512 - 0s - loss: 2837.1430 - mean_absolute_error: 52.7758 - val_loss: 2763.3239 - val_mean_absolute_error: 52.0668
# Epoch 10/200
# 14512/14512 - 0s - loss: 2681.3448 - mean_absolute_error: 51.2644 - val_loss: 2612.4954 - val_mean_absolute_error: 50.5801
# Epoch 11/200
# 14512/14512 - 0s - loss: 2532.8129 - mean_absolute_error: 49.7798 - val_loss: 2467.4883 - val_mean_absolute_error: 49.1086
# Epoch 12/200
# 14512/14512 - 0s - loss: 2388.8985 - mean_absolute_error: 48.3018 - val_loss: 2326.0944 - val_mean_absolute_error: 47.6353
# Epoch 13/200
# 14512/14512 - 0s - loss: 2252.2335 - mean_absolute_error: 46.8511 - val_loss: 2192.9090 - val_mean_absolute_error: 46.1993
# Epoch 14/200
# 14512/14512 - 0s - loss: 2120.0921 - mean_absolute_error: 45.4077 - val_loss: 2063.5414 - val_mean_absolute_error: 44.7637
# Epoch 15/200
# 14512/14512 - 0s - loss: 1993.8940 - mean_absolute_error: 43.9851 - val_loss: 1940.9461 - val_mean_absolute_error: 43.3579
# Epoch 16/200
# 14512/14512 - 0s - loss: 1872.8638 - mean_absolute_error: 42.5831 - val_loss: 1823.4546 - val_mean_absolute_error: 41.9715
# Epoch 17/200
# 14512/14512 - 0s - loss: 1754.0473 - mean_absolute_error: 41.1711 - val_loss: 1707.5921 - val_mean_absolute_error: 40.5721
# Epoch 18/200
# 14512/14512 - 0s - loss: 1640.7484 - mean_absolute_error: 39.7788 - val_loss: 1597.0746 - val_mean_absolute_error: 39.1898
# Epoch 19/200
# 14512/14512 - 0s - loss: 1531.7668 - mean_absolute_error: 38.3991 - val_loss: 1489.4276 - val_mean_absolute_error: 37.8106
# Epoch 20/200
# 14512/14512 - 0s - loss: 1426.2876 - mean_absolute_error: 37.0260 - val_loss: 1385.5074 - val_mean_absolute_error: 36.4405
# Epoch 21/200
# 14512/14512 - 0s - loss: 1325.1503 - mean_absolute_error: 35.6609 - val_loss: 1287.1229 - val_mean_absolute_error: 35.0888
# Epoch 22/200
# 14512/14512 - 0s - loss: 1228.3877 - mean_absolute_error: 34.3079 - val_loss: 1192.4208 - val_mean_absolute_error: 33.7405
# Epoch 23/200
# 14512/14512 - 0s - loss: 1136.0055 - mean_absolute_error: 32.9617 - val_loss: 1102.6986 - val_mean_absolute_error: 32.4117
# Epoch 24/200
# 14512/14512 - 0s - loss: 1048.4261 - mean_absolute_error: 31.6352 - val_loss: 1016.8567 - val_mean_absolute_error: 31.0919
# Epoch 25/200
# 14512/14512 - 0s - loss: 965.2824 - mean_absolute_error: 30.3212 - val_loss: 934.8963 - val_mean_absolute_error: 29.7830
# Epoch 26/200
# 14512/14512 - 0s - loss: 886.5476 - mean_absolute_error: 29.0225 - val_loss: 857.1713 - val_mean_absolute_error: 28.4869
# Epoch 27/200
# 14512/14512 - 0s - loss: 812.1771 - mean_absolute_error: 27.7395 - val_loss: 783.2272 - val_mean_absolute_error: 27.2029
# Epoch 28/200
# 14512/14512 - 0s - loss: 741.9988 - mean_absolute_error: 26.4735 - val_loss: 715.3819 - val_mean_absolute_error: 25.9488
# Epoch 29/200
# 14512/14512 - 0s - loss: 676.4278 - mean_absolute_error: 25.2289 - val_loss: 650.4875 - val_mean_absolute_error: 24.7024
# Epoch 30/200
# 14512/14512 - 0s - loss: 615.4333 - mean_absolute_error: 24.0065 - val_loss: 590.5227 - val_mean_absolute_error: 23.4811
# Epoch 31/200
# 14512/14512 - 0s - loss: 558.6059 - mean_absolute_error: 22.8032 - val_loss: 534.6769 - val_mean_absolute_error: 22.2807
# Epoch 32/200
# 14512/14512 - 0s - loss: 505.9499 - mean_absolute_error: 21.6257 - val_loss: 483.8157 - val_mean_absolute_error: 21.1145
# Epoch 33/200
# 14512/14512 - 0s - loss: 457.1645 - mean_absolute_error: 20.4718 - val_loss: 438.4002 - val_mean_absolute_error: 19.9860
# Epoch 34/200
# 14512/14512 - 0s - loss: 412.0430 - mean_absolute_error: 19.3433 - val_loss: 394.7028 - val_mean_absolute_error: 18.8654
# Epoch 35/200
# 14512/14512 - 0s - loss: 370.3531 - mean_absolute_error: 18.2357 - val_loss: 354.2595 - val_mean_absolute_error: 17.7650
# Epoch 36/200
# 14512/14512 - 0s - loss: 331.8828 - mean_absolute_error: 17.1540 - val_loss: 317.1695 - val_mean_absolute_error: 16.6918
# Epoch 37/200
# 14512/14512 - 0s - loss: 296.4322 - mean_absolute_error: 16.0912 - val_loss: 282.8871 - val_mean_absolute_error: 15.6387
# Epoch 38/200
# 14512/14512 - 0s - loss: 264.0644 - mean_absolute_error: 15.0599 - val_loss: 251.7362 - val_mean_absolute_error: 14.6164
# Epoch 39/200
# 14512/14512 - 0s - loss: 234.6110 - mean_absolute_error: 14.0549 - val_loss: 223.7250 - val_mean_absolute_error: 13.6296
# Epoch 40/200
# 14512/14512 - 0s - loss: 207.8896 - mean_absolute_error: 13.0853 - val_loss: 199.1262 - val_mean_absolute_error: 12.6849
# Epoch 41/200
# 14512/14512 - 0s - loss: 183.7641 - mean_absolute_error: 12.1497 - val_loss: 176.4350 - val_mean_absolute_error: 11.7667
# Epoch 42/200
# 14512/14512 - 0s - loss: 162.1333 - mean_absolute_error: 11.2528 - val_loss: 155.6842 - val_mean_absolute_error: 10.8870
# Epoch 43/200
# 14512/14512 - 0s - loss: 142.8628 - mean_absolute_error: 10.4052 - val_loss: 137.1777 - val_mean_absolute_error: 10.0609
# Epoch 44/200
# 14512/14512 - 0s - loss: 125.7999 - mean_absolute_error: 9.6112 - val_loss: 120.8228 - val_mean_absolute_error: 9.2883
# Epoch 45/200
# 14512/14512 - 0s - loss: 110.7721 - mean_absolute_error: 8.8717 - val_loss: 106.4482 - val_mean_absolute_error: 8.5716
# Epoch 46/200
# 14512/14512 - 0s - loss: 97.7224 - mean_absolute_error: 8.2004 - val_loss: 93.9718 - val_mean_absolute_error: 7.9240
# Epoch 47/200
# 14512/14512 - 0s - loss: 86.4372 - mean_absolute_error: 7.5957 - val_loss: 83.2727 - val_mean_absolute_error: 7.3566
# Epoch 48/200
# 14512/14512 - 0s - loss: 76.7645 - mean_absolute_error: 7.0642 - val_loss: 74.1979 - val_mean_absolute_error: 6.8559
# Epoch 49/200
# 14512/14512 - 0s - loss: 68.4262 - mean_absolute_error: 6.5903 - val_loss: 65.2660 - val_mean_absolute_error: 6.3830
# Epoch 50/200
# 14512/14512 - 0s - loss: 61.1314 - mean_absolute_error: 6.1613 - val_loss: 57.6656 - val_mean_absolute_error: 5.9567
# Epoch 51/200
# 14512/14512 - 0s - loss: 54.4773 - mean_absolute_error: 5.7405 - val_loss: 51.1952 - val_mean_absolute_error: 5.5482
# Epoch 52/200
# 14512/14512 - 0s - loss: 48.5918 - mean_absolute_error: 5.3438 - val_loss: 45.0595 - val_mean_absolute_error: 5.1613
# Epoch 53/200
# 14512/14512 - 0s - loss: 43.4663 - mean_absolute_error: 4.9831 - val_loss: 40.1439 - val_mean_absolute_error: 4.8149
# Epoch 54/200
# 14512/14512 - 0s - loss: 38.7445 - mean_absolute_error: 4.6348 - val_loss: 35.2590 - val_mean_absolute_error: 4.4384
# Epoch 55/200
# 14512/14512 - 0s - loss: 34.5460 - mean_absolute_error: 4.3041 - val_loss: 31.4594 - val_mean_absolute_error: 4.1427
# Epoch 56/200
# 14512/14512 - 0s - loss: 31.0064 - mean_absolute_error: 4.0219 - val_loss: 28.4133 - val_mean_absolute_error: 3.8929
# Epoch 57/200
# 14512/14512 - 0s - loss: 27.8087 - mean_absolute_error: 3.7570 - val_loss: 25.3782 - val_mean_absolute_error: 3.6458
# Epoch 58/200
# 14512/14512 - 0s - loss: 25.1197 - mean_absolute_error: 3.5339 - val_loss: 22.7352 - val_mean_absolute_error: 3.4113
# Epoch 59/200
# 14512/14512 - 0s - loss: 22.7371 - mean_absolute_error: 3.3305 - val_loss: 20.6798 - val_mean_absolute_error: 3.2303
# Epoch 60/200
# 14512/14512 - 0s - loss: 20.6484 - mean_absolute_error: 3.1381 - val_loss: 18.7407 - val_mean_absolute_error: 3.0357
# Epoch 61/200
# 14512/14512 - 0s - loss: 18.8709 - mean_absolute_error: 2.9768 - val_loss: 17.3070 - val_mean_absolute_error: 2.9204
# Epoch 62/200
# 14512/14512 - 0s - loss: 17.3851 - mean_absolute_error: 2.8447 - val_loss: 15.8573 - val_mean_absolute_error: 2.7670
# Epoch 63/200
# 14512/14512 - 0s - loss: 16.0667 - mean_absolute_error: 2.7174 - val_loss: 14.8306 - val_mean_absolute_error: 2.6669
# Epoch 64/200
# 14512/14512 - 0s - loss: 14.9203 - mean_absolute_error: 2.6088 - val_loss: 13.8085 - val_mean_absolute_error: 2.5706
# Epoch 65/200
# 14512/14512 - 0s - loss: 13.9410 - mean_absolute_error: 2.5158 - val_loss: 12.9678 - val_mean_absolute_error: 2.4921
# Epoch 66/200
# 14512/14512 - 0s - loss: 13.0137 - mean_absolute_error: 2.4285 - val_loss: 12.3358 - val_mean_absolute_error: 2.4407
# Epoch 67/200
# 14512/14512 - 0s - loss: 12.2719 - mean_absolute_error: 2.3595 - val_loss: 11.7375 - val_mean_absolute_error: 2.3744
# Epoch 68/200
# 14512/14512 - 0s - loss: 11.6058 - mean_absolute_error: 2.2924 - val_loss: 11.0250 - val_mean_absolute_error: 2.2999
# Epoch 69/200
# 14512/14512 - 0s - loss: 10.8580 - mean_absolute_error: 2.2147 - val_loss: 10.3999 - val_mean_absolute_error: 2.2324
# Epoch 70/200
# 14512/14512 - 0s - loss: 10.2648 - mean_absolute_error: 2.1582 - val_loss: 9.9415 - val_mean_absolute_error: 2.1620
# Epoch 71/200
# 14512/14512 - 0s - loss: 9.7965 - mean_absolute_error: 2.1092 - val_loss: 9.4759 - val_mean_absolute_error: 2.1180
# Epoch 72/200
# 14512/14512 - 0s - loss: 9.2606 - mean_absolute_error: 2.0512 - val_loss: 9.1407 - val_mean_absolute_error: 2.0852
# Epoch 73/200
# 14512/14512 - 0s - loss: 8.8436 - mean_absolute_error: 2.0067 - val_loss: 8.8623 - val_mean_absolute_error: 2.0365
# Epoch 74/200
# 14512/14512 - 0s - loss: 8.4472 - mean_absolute_error: 1.9606 - val_loss: 8.5837 - val_mean_absolute_error: 1.9987
# Epoch 75/200
# 14512/14512 - 0s - loss: 8.1206 - mean_absolute_error: 1.9231 - val_loss: 8.5112 - val_mean_absolute_error: 2.0070
# Epoch 76/200
# 14512/14512 - 0s - loss: 7.8023 - mean_absolute_error: 1.8850 - val_loss: 8.1434 - val_mean_absolute_error: 1.9454
# Epoch 77/200
# 14512/14512 - 0s - loss: 7.5104 - mean_absolute_error: 1.8535 - val_loss: 7.8075 - val_mean_absolute_error: 1.9016
# Epoch 78/200
# 14512/14512 - 0s - loss: 7.1906 - mean_absolute_error: 1.8124 - val_loss: 7.4834 - val_mean_absolute_error: 1.8573
# Epoch 79/200
# 14512/14512 - 0s - loss: 6.9455 - mean_absolute_error: 1.7776 - val_loss: 7.2991 - val_mean_absolute_error: 1.8334
# Epoch 80/200
# 14512/14512 - 0s - loss: 6.7036 - mean_absolute_error: 1.7452 - val_loss: 7.1549 - val_mean_absolute_error: 1.8238
# Epoch 81/200
# 14512/14512 - 0s - loss: 6.4511 - mean_absolute_error: 1.7134 - val_loss: 6.9871 - val_mean_absolute_error: 1.8044
# Epoch 82/200
# 14512/14512 - 0s - loss: 6.2417 - mean_absolute_error: 1.6856 - val_loss: 6.9556 - val_mean_absolute_error: 1.7760
# Epoch 83/200
# 14512/14512 - 0s - loss: 6.0382 - mean_absolute_error: 1.6526 - val_loss: 6.7979 - val_mean_absolute_error: 1.7469
# Epoch 84/200
# 14512/14512 - 0s - loss: 5.8652 - mean_absolute_error: 1.6202 - val_loss: 7.4346 - val_mean_absolute_error: 1.8538
# Epoch 85/200
# 14512/14512 - 0s - loss: 5.8814 - mean_absolute_error: 1.6329 - val_loss: 6.6485 - val_mean_absolute_error: 1.7070
# Epoch 86/200
# 14512/14512 - 0s - loss: 5.5451 - mean_absolute_error: 1.5746 - val_loss: 6.6018 - val_mean_absolute_error: 1.6897
# Epoch 87/200
# 14512/14512 - 0s - loss: 5.3969 - mean_absolute_error: 1.5532 - val_loss: 6.4735 - val_mean_absolute_error: 1.6767
# Epoch 88/200
# 14512/14512 - 0s - loss: 5.2662 - mean_absolute_error: 1.5304 - val_loss: 6.2616 - val_mean_absolute_error: 1.6298
# Epoch 89/200
# 14512/14512 - 0s - loss: 5.1412 - mean_absolute_error: 1.5072 - val_loss: 6.2838 - val_mean_absolute_error: 1.6351
# Epoch 90/200
# 14512/14512 - 0s - loss: 5.0641 - mean_absolute_error: 1.4954 - val_loss: 6.1506 - val_mean_absolute_error: 1.6208
# Epoch 91/200
# 14512/14512 - 0s - loss: 4.8511 - mean_absolute_error: 1.4665 - val_loss: 5.9402 - val_mean_absolute_error: 1.6129
# Epoch 92/200
# 14512/14512 - 0s - loss: 4.7291 - mean_absolute_error: 1.4692 - val_loss: 5.6608 - val_mean_absolute_error: 1.5702
# Epoch 93/200
# 14512/14512 - 0s - loss: 4.3653 - mean_absolute_error: 1.4139 - val_loss: 5.2361 - val_mean_absolute_error: 1.5236
# Epoch 94/200
# 14512/14512 - 0s - loss: 4.2076 - mean_absolute_error: 1.3999 - val_loss: 4.8176 - val_mean_absolute_error: 1.4826
# Epoch 95/200
# 14512/14512 - 0s - loss: 4.0324 - mean_absolute_error: 1.3739 - val_loss: 4.8539 - val_mean_absolute_error: 1.4750
# Epoch 96/200
# 14512/14512 - 0s - loss: 3.9434 - mean_absolute_error: 1.3650 - val_loss: 4.7325 - val_mean_absolute_error: 1.5124
# Epoch 97/200
# 14512/14512 - 0s - loss: 3.7710 - mean_absolute_error: 1.3372 - val_loss: 4.4254 - val_mean_absolute_error: 1.4404
# Epoch 98/200
# 14512/14512 - 0s - loss: 3.6708 - mean_absolute_error: 1.3194 - val_loss: 4.4182 - val_mean_absolute_error: 1.4142
# Epoch 99/200
# 14512/14512 - 0s - loss: 3.5623 - mean_absolute_error: 1.3077 - val_loss: 4.2554 - val_mean_absolute_error: 1.4156
# Epoch 100/200
# 14512/14512 - 0s - loss: 3.4221 - mean_absolute_error: 1.2938 - val_loss: 4.2251 - val_mean_absolute_error: 1.4144
# Epoch 101/200
# 14512/14512 - 0s - loss: 3.3769 - mean_absolute_error: 1.2851 - val_loss: 4.2107 - val_mean_absolute_error: 1.4132
# Epoch 102/200
# 14512/14512 - 0s - loss: 3.2835 - mean_absolute_error: 1.2684 - val_loss: 4.0329 - val_mean_absolute_error: 1.3901
# Epoch 103/200
# 14512/14512 - 0s - loss: 3.2226 - mean_absolute_error: 1.2623 - val_loss: 3.9666 - val_mean_absolute_error: 1.3710
# Epoch 104/200
# 14512/14512 - 0s - loss: 3.1848 - mean_absolute_error: 1.2579 - val_loss: 3.8707 - val_mean_absolute_error: 1.3703
# Epoch 105/200
# 14512/14512 - 0s - loss: 3.1281 - mean_absolute_error: 1.2515 - val_loss: 3.8396 - val_mean_absolute_error: 1.3683
# Epoch 106/200
# 14512/14512 - 0s - loss: 3.0631 - mean_absolute_error: 1.2407 - val_loss: 3.8117 - val_mean_absolute_error: 1.3486
# Epoch 107/200
# 14512/14512 - 0s - loss: 3.0483 - mean_absolute_error: 1.2390 - val_loss: 3.7912 - val_mean_absolute_error: 1.3531
# Epoch 108/200
# 14512/14512 - 0s - loss: 3.0060 - mean_absolute_error: 1.2293 - val_loss: 3.8142 - val_mean_absolute_error: 1.3532
# Epoch 109/200
# 14512/14512 - 0s - loss: 2.9948 - mean_absolute_error: 1.2286 - val_loss: 3.8692 - val_mean_absolute_error: 1.3673
# Epoch 110/200
# 14512/14512 - 0s - loss: 2.9667 - mean_absolute_error: 1.2249 - val_loss: 3.6664 - val_mean_absolute_error: 1.3282
# Epoch 111/200
# 14512/14512 - 0s - loss: 2.9814 - mean_absolute_error: 1.2311 - val_loss: 3.7586 - val_mean_absolute_error: 1.3450
# Epoch 112/200
# 14512/14512 - 0s - loss: 2.9427 - mean_absolute_error: 1.2179 - val_loss: 3.7475 - val_mean_absolute_error: 1.3504
# Epoch 113/200
# 14512/14512 - 0s - loss: 2.8936 - mean_absolute_error: 1.2099 - val_loss: 3.6693 - val_mean_absolute_error: 1.3175
# Epoch 114/200
# 14512/14512 - 0s - loss: 2.9045 - mean_absolute_error: 1.2200 - val_loss: 3.6644 - val_mean_absolute_error: 1.3332
# Epoch 115/200
# 14512/14512 - 0s - loss: 2.8407 - mean_absolute_error: 1.1993 - val_loss: 3.6387 - val_mean_absolute_error: 1.3241
# Epoch 116/200
# 14512/14512 - 0s - loss: 2.8003 - mean_absolute_error: 1.1894 - val_loss: 3.6791 - val_mean_absolute_error: 1.3246
# Epoch 117/200
# 14512/14512 - 0s - loss: 2.8068 - mean_absolute_error: 1.1970 - val_loss: 3.6062 - val_mean_absolute_error: 1.3085
# Epoch 118/200
# 14512/14512 - 0s - loss: 2.8204 - mean_absolute_error: 1.1986 - val_loss: 3.5806 - val_mean_absolute_error: 1.3030
# Epoch 119/200
# 14512/14512 - 0s - loss: 2.7855 - mean_absolute_error: 1.1872 - val_loss: 3.6101 - val_mean_absolute_error: 1.3145
# Epoch 120/200
# 14512/14512 - 0s - loss: 2.7655 - mean_absolute_error: 1.1847 - val_loss: 3.7733 - val_mean_absolute_error: 1.3459
# Epoch 121/200
# 14512/14512 - 0s - loss: 2.7798 - mean_absolute_error: 1.1909 - val_loss: 3.7599 - val_mean_absolute_error: 1.3502
# Epoch 122/200
# 14512/14512 - 0s - loss: 2.7672 - mean_absolute_error: 1.1862 - val_loss: 3.7655 - val_mean_absolute_error: 1.3485

# %%
val_loss = hist.history["val_loss"][1:]
loss = hist.history["loss"][1:]
epochs = range(1, len(val_loss)+1)

plt.plot(epochs, loss, color = "b")
plt.plot(epochs, val_loss, color = "r")
plt.xlabel("No. of Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
# Out:
# Text(0, 0.5, 'Loss')

# %%
val_error = hist.history["val_mean_absolute_error"][1:]
training_error = hist.history["mean_absolute_error"][1:]
epochs = range(1, len(val_error)+1)

plt.plot(epochs, training_error, color = "b")
plt.plot(epochs, val_error, color = "r")
#plt.yticks(np.arange(0, max(training_error), 1))
#plt.xticks(np.arange(0, max(epochs)+1, 5))
plt.xlabel("No. of Epochs", fontsize=15)
plt.ylabel("Error", fontsize=15)
plt.show()

# %% [markdown]
# ## Evaluating the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 1814/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
print ("Test Loss: {:.2f}, Expected Deviation for Prediction: {:.2f}".format(test_loss, test_accuracy))
# Out:
# Test Loss: 4.31, Expected Deviation for Prediction: 1.39
